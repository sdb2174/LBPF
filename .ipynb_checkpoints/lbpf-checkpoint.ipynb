# %%
import tensorflow as tf 
import numpy as np 
import imageio
import matplotlib.pyplot as plt
from MTRB import MTRB
from GTMB import GTMB
from LTMB import LTMB

# %%
tf.compat.v1.disable_eager_execution()

# %%
img = imageio.imread('proj_files/train/000000.png')
print(np.shape(img))
# Out:
# (1024, 1024, 3)

# %%
output_list = []
d_list_a = (1,2,3,2,1)
d_list_b = (1,2,3,2,1)
d_list_c = (1,2,2,2,1)
# Branch I ############################################################################################
inputs = tf.keras.Input(shape = (1024, 1024, 3), name = "img")
inputs_ = tf.nn.space_to_depth(inputs, 2)
t1 = tf.keras.layers.Conv2D(128, kernel_size = (3, 3), padding = "same", activation = "relu") (inputs_)
t1 = MTRB(t1, d_list_a)
########################################################################################################

# Branch II ###########################################################################################
t2 = tf.keras.layers.ZeroPadding2D(padding=(1,1))(t1)
t2 = tf.keras.layers.Conv2D(128, kernel_size = (3, 3), padding = "valid", activation = "relu", strides = (2, 2)) (t2)
t2 = MTRB(t2, d_list_b)
########################################################################################################

# Branch III ###########################################################################################
t3 = tf.keras.layers.ZeroPadding2D(padding=(1,1))(t2)
t3 = tf.keras.layers.Conv2D(128, kernel_size = (3, 3), padding = "valid", activation = "relu", strides = (2, 2)) (t3)
t3 = MTRB(t3, d_list_c)
# t3 = GTMB(t3)
# t3 = LTMB(t3, d_list_c)
t3 = tf.keras.layers.Conv2D(12, kernel_size = (3, 3), padding = "same") (t3)
t3_out = tf.nn.depth_to_space(t3, 2)
output_list.append(t3_out)
########################################################################################################

# Branch II (cont.) ####################################################################################
_t2 = tf.keras.layers.Concatenate()([t3_out, t2])
_t2 = tf.keras.layers.Conv2D(128, kernel_size = (3, 3), padding = "same", activation = "relu") (_t2)
# _t2 = GTMB(_t2)
_t2 = MTRB(_t2, d_list_b)
# _t2 = GTMB(_t2)
# _t2 = LTMB(_t2, d_list_b)
_t2 = tf.keras.layers.Conv2D(12, kernel_size = (3, 3), padding = "same") (_t2)
t2_out = tf.nn.depth_to_space(_t2, 2)
output_list.append(t2_out)
########################################################################################################

# Branch I (cont.) #####################################################################################
_t1 = tf.keras.layers.Concatenate()([t1, t2_out])
_t1 = tf.keras.layers.Conv2D(128, kernel_size = (3, 3), padding = "same", activation = "relu") (_t1)
# _t1 = GTMB(_t1)
_t1 = MTRB(_t1, d_list_a)
# _t1 = GTMB(_t1) 
# _t1 = LTMB(_t1, d_list_a)
_t1 = tf.keras.layers.Conv2D(12, kernel_size = (3, 3), padding = "same") (_t1)
output = tf.nn.depth_to_space(_t1, 2)
output_list.append(output)
########################################################################################################

# %%
model = tf.keras.Model(inputs, output, name = "lbpf")

# %%
model.summary()
tf.keras.utils.plot_model(model, "LBPF.png", show_shapes = True)
# Out:
# Model: "lbpf"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# img (InputLayer)                [(None, 1024, 1024,  0
# __________________________________________________________________________________________________
# tf_op_layer_SpaceToDepth (Tenso [(None, 512, 512, 12 0           img[0][0]
# __________________________________________________________________________________________________
# conv2d (Conv2D)                 (None, 512, 512, 128 13952       tf_op_layer_SpaceToDepth[0][0]
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, 512, 512, 64) 73792       conv2d[0][0]
# __________________________________________________________________________________________________
# concatenate (Concatenate)       (None, 512, 512, 192 0           conv2d_1[0][0]
#                                                                  conv2d[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, 512, 512, 64) 110656      concatenate[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, 512, 512, 256 0           conv2d_2[0][0]
#                                                                  concatenate[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, 512, 512, 64) 147520      concatenate_1[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 512, 512, 320 0           conv2d_3[0][0]
#                                                                  concatenate_1[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, 512, 512, 64) 184384      concatenate_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 512, 512, 384 0           conv2d_4[0][0]
#                                                                  concatenate_2[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 512, 512, 64) 221248      concatenate_3[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 512, 512, 448 0           conv2d_5[0][0]
#                                                                  concatenate_3[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, 512, 512, 64) 258112      concatenate_4[0][0]
# __________________________________________________________________________________________________
# adaptive_implicit_trans (adapti (None, 512, 512, 64) 64          conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, 512, 512, 128 8320        adaptive_implicit_trans[0][0]
# __________________________________________________________________________________________________
# add (Add)                       (None, 512, 512, 128 0           conv2d[0][0]
#                                                                  conv2d_7[0][0]
# __________________________________________________________________________________________________
# zero_padding2d (ZeroPadding2D)  (None, 514, 514, 128 0           add[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, 256, 256, 128 147584      zero_padding2d[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 256, 256, 64) 73792       conv2d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 256, 256, 192 0           conv2d_9[0][0]
#                                                                  conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 256, 256, 64) 110656      concatenate_5[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 256, 256, 256 0           conv2d_10[0][0]
#                                                                  concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 256, 256, 64) 147520      concatenate_6[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 256, 256, 320 0           conv2d_11[0][0]
#                                                                  concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 256, 256, 64) 184384      concatenate_7[0][0]
# __________________________________________________________________________________________________
# concatenate_8 (Concatenate)     (None, 256, 256, 384 0           conv2d_12[0][0]
#                                                                  concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 256, 256, 64) 221248      concatenate_8[0][0]
# __________________________________________________________________________________________________
# concatenate_9 (Concatenate)     (None, 256, 256, 448 0           conv2d_13[0][0]
#                                                                  concatenate_8[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 256, 256, 64) 258112      concatenate_9[0][0]
# __________________________________________________________________________________________________
# adaptive_implicit_trans_1 (adap (None, 256, 256, 64) 64          conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 256, 256, 128 8320        adaptive_implicit_trans_1[0][0]
# __________________________________________________________________________________________________
# add_1 (Add)                     (None, 256, 256, 128 0           conv2d_8[0][0]
#                                                                  conv2d_15[0][0]
# __________________________________________________________________________________________________
# zero_padding2d_1 (ZeroPadding2D (None, 258, 258, 128 0           add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 128, 128, 128 147584      zero_padding2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 128, 128, 64) 73792       conv2d_16[0][0]
# __________________________________________________________________________________________________
# concatenate_10 (Concatenate)    (None, 128, 128, 192 0           conv2d_17[0][0]
#                                                                  conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, 128, 128, 64) 110656      concatenate_10[0][0]
# __________________________________________________________________________________________________
# concatenate_11 (Concatenate)    (None, 128, 128, 256 0           conv2d_18[0][0]
#                                                                  concatenate_10[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, 128, 128, 64) 147520      concatenate_11[0][0]
# __________________________________________________________________________________________________
# concatenate_12 (Concatenate)    (None, 128, 128, 320 0           conv2d_19[0][0]
#                                                                  concatenate_11[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, 128, 128, 64) 184384      concatenate_12[0][0]
# __________________________________________________________________________________________________
# concatenate_13 (Concatenate)    (None, 128, 128, 384 0           conv2d_20[0][0]
#                                                                  concatenate_12[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, 128, 128, 64) 221248      concatenate_13[0][0]
# __________________________________________________________________________________________________
# concatenate_14 (Concatenate)    (None, 128, 128, 448 0           conv2d_21[0][0]
#                                                                  concatenate_13[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, 128, 128, 64) 258112      concatenate_14[0][0]
# __________________________________________________________________________________________________
# adaptive_implicit_trans_2 (adap (None, 128, 128, 64) 64          conv2d_22[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, 128, 128, 128 8320        adaptive_implicit_trans_2[0][0]
# __________________________________________________________________________________________________
# add_2 (Add)                     (None, 128, 128, 128 0           conv2d_16[0][0]
#                                                                  conv2d_23[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, 128, 128, 12) 13836       add_2[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_DepthToSpace (Tenso [(None, 256, 256, 3) 0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# concatenate_15 (Concatenate)    (None, 256, 256, 131 0           tf_op_layer_DepthToSpace[0][0]
#                                                                  add_1[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, 256, 256, 128 151040      concatenate_15[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, 256, 256, 64) 73792       conv2d_25[0][0]
# __________________________________________________________________________________________________
# concatenate_16 (Concatenate)    (None, 256, 256, 192 0           conv2d_26[0][0]
#                                                                  conv2d_25[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, 256, 256, 64) 110656      concatenate_16[0][0]
# __________________________________________________________________________________________________
# concatenate_17 (Concatenate)    (None, 256, 256, 256 0           conv2d_27[0][0]
#                                                                  concatenate_16[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, 256, 256, 64) 147520      concatenate_17[0][0]
# __________________________________________________________________________________________________
# concatenate_18 (Concatenate)    (None, 256, 256, 320 0           conv2d_28[0][0]
#                                                                  concatenate_17[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, 256, 256, 64) 184384      concatenate_18[0][0]
# __________________________________________________________________________________________________
# concatenate_19 (Concatenate)    (None, 256, 256, 384 0           conv2d_29[0][0]
#                                                                  concatenate_18[0][0]
# __________________________________________________________________________________________________
# conv2d_30 (Conv2D)              (None, 256, 256, 64) 221248      concatenate_19[0][0]
# __________________________________________________________________________________________________
# concatenate_20 (Concatenate)    (None, 256, 256, 448 0           conv2d_30[0][0]
#                                                                  concatenate_19[0][0]
# __________________________________________________________________________________________________
# conv2d_31 (Conv2D)              (None, 256, 256, 64) 258112      concatenate_20[0][0]
# __________________________________________________________________________________________________
# adaptive_implicit_trans_3 (adap (None, 256, 256, 64) 64          conv2d_31[0][0]
# __________________________________________________________________________________________________
# conv2d_32 (Conv2D)              (None, 256, 256, 128 8320        adaptive_implicit_trans_3[0][0]
# __________________________________________________________________________________________________
# add_3 (Add)                     (None, 256, 256, 128 0           conv2d_25[0][0]
#                                                                  conv2d_32[0][0]
# __________________________________________________________________________________________________
# conv2d_33 (Conv2D)              (None, 256, 256, 12) 13836       add_3[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_DepthToSpace_1 (Ten [(None, 512, 512, 3) 0           conv2d_33[0][0]
# __________________________________________________________________________________________________
# concatenate_21 (Concatenate)    (None, 512, 512, 131 0           add[0][0]
#                                                                  tf_op_layer_DepthToSpace_1[0][0]
# __________________________________________________________________________________________________
# conv2d_34 (Conv2D)              (None, 512, 512, 128 151040      concatenate_21[0][0]
# __________________________________________________________________________________________________
# conv2d_35 (Conv2D)              (None, 512, 512, 64) 73792       conv2d_34[0][0]
# __________________________________________________________________________________________________
# concatenate_22 (Concatenate)    (None, 512, 512, 192 0           conv2d_35[0][0]
#                                                                  conv2d_34[0][0]
# __________________________________________________________________________________________________
# conv2d_36 (Conv2D)              (None, 512, 512, 64) 110656      concatenate_22[0][0]
# __________________________________________________________________________________________________
# concatenate_23 (Concatenate)    (None, 512, 512, 256 0           conv2d_36[0][0]
#                                                                  concatenate_22[0][0]
# __________________________________________________________________________________________________
# conv2d_37 (Conv2D)              (None, 512, 512, 64) 147520      concatenate_23[0][0]
# __________________________________________________________________________________________________
# concatenate_24 (Concatenate)    (None, 512, 512, 320 0           conv2d_37[0][0]
#                                                                  concatenate_23[0][0]
# __________________________________________________________________________________________________
# conv2d_38 (Conv2D)              (None, 512, 512, 64) 184384      concatenate_24[0][0]
# __________________________________________________________________________________________________
# concatenate_25 (Concatenate)    (None, 512, 512, 384 0           conv2d_38[0][0]
#                                                                  concatenate_24[0][0]
# __________________________________________________________________________________________________
# conv2d_39 (Conv2D)              (None, 512, 512, 64) 221248      concatenate_25[0][0]
# __________________________________________________________________________________________________
# concatenate_26 (Concatenate)    (None, 512, 512, 448 0           conv2d_39[0][0]
#                                                                  concatenate_25[0][0]
# __________________________________________________________________________________________________
# conv2d_40 (Conv2D)              (None, 512, 512, 64) 258112      concatenate_26[0][0]
# __________________________________________________________________________________________________
# adaptive_implicit_trans_4 (adap (None, 512, 512, 64) 64          conv2d_40[0][0]
# __________________________________________________________________________________________________
# conv2d_41 (Conv2D)              (None, 512, 512, 128 8320        adaptive_implicit_trans_4[0][0]
# __________________________________________________________________________________________________
# add_4 (Add)                     (None, 512, 512, 128 0           conv2d_34[0][0]
#                                                                  conv2d_41[0][0]
# __________________________________________________________________________________________________
# conv2d_42 (Conv2D)              (None, 512, 512, 12) 13836       add_4[0][0]
# __________________________________________________________________________________________________
# tf_op_layer_DepthToSpace_2 (Ten [(None, 1024, 1024,  0           conv2d_42[0][0]
# ==================================================================================================
# Total params: 5,673,188
# Trainable params: 5,673,188
# Non-trainable params: 0
# __________________________________________________________________________________________________
# ('You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) ', 'for plot_model/model_to_dot to work.')

# %%
X_train = np.zeros((100, 1024, 1024, 3)) # Change to 100 when ready to introduce all data
folder = 'proj_files/train/' 
ext = '.png' 

for i in range(10):
    file = folder + '00000' + str(i) + ext 
    print("reading", file)
    X_train[i, :, :, :] = imageio.imread(file)

for i in range(10, 100):
    file = folder + '0000' + str(i) + ext 
    print("reading", file)
    X_train[i, :, :, :] = imageio.imread(file)
    
y_train = np.zeros((100, 1024, 1024, 3)) # Change to 100 when ready to introduce all data
folder = 'proj_files/validation/' 
for i in range(10):
    file = folder + '00000' + str(i) + ext 
    print("reading", file)
    y_train[i, :, :, :] = imageio.imread(file)

# reading proj_files/validation/000092.png
# reading proj_files/validation/000093.png
# reading proj_files/validation/000094.png
# reading proj_files/validation/000095.png
# reading proj_files/validation/000096.png
# reading proj_files/validation/000097.png
# reading proj_files/validation/000098.png
# reading proj_files/validation/000099.png
# (100, 1024, 1024, 3)
# (100, 1024, 1024, 3)

# %%
X_train_s = X_train / 255.0

fig1, axes1 = plt.subplots(5, 5, figsize=(8, 8))
for j in range(5):
    for k in range(5):
        i = np.random.choice(range(len(X_train_s)))
        axes1[j][k].set_axis_off()
        axes1[j][k].imshow(X_train_s[i:i+1][0], cmap = 'viridis')

# %%
y_train_s = y_train / 255.0

fig1, axes1 = plt.subplots(5, 5, figsize=(8, 8))
for j in range(5):
    for k in range(5):
        i = np.random.choice(range(len(y_train_s)))
        axes1[j][k].set_axis_off()
        axes1[j][k].imshow(y_train_s[i:i+1][0], cmap = 'viridis')

# %%
model.compile(optimizer = 'adam', loss = 'mean_absolute_error', metrics = [tf.keras.metrics.MeanAbsoluteError()])

# %%
history = model.fit(x = X_train_s, y = y_train_s, batch_size = 8, epochs = 5)
# Out:
# Train on 100 samples
# Epoch 1/5
# 100/100 [==============================] - 2127s 21s/sample - loss: 0.8580 - mean_absolute_error: 0.8580
# Epoch 2/5
#  80/100 [=======================>......] - ETA: 7:09 - loss: 0.1327 - mean_absolute_error: 0.1327

# %%
# tf.keras.models.save_model(model, "") not working: ValueError: Unable to save function b'__inference__wrapped_model_20035' because it captures graph tensor Tensor("mul:0", shape=(1, 1, 64, 64), dtype=float32) from a parent function which cannot be converted to a constant with `tf.get_static_value`
model_json = model.to_json()

with open("model.json", "w") as json_file:
    json_file.write(model_json)

# Warning acquired: /home/ecbm4040/envTF24/lib/python3.6/site-packages/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument. category=CustomMaskWarning)

# %%
model.save_weights("model.h5")

# %%
X_test = np.zeros((100, 1024, 1024, 3)) # Change to 100 when ready to introduce all data
folder = 'proj_files/test/' 
ext = '.png' 

for i in range(10):
    file = folder + '00000' + str(i) + ext 
    print("reading", file)
    X_test[i, :, :, :] = imageio.imread(file)

for i in range(10, 100):
    file = folder + '0000' + str(i) + ext 
    print("reading", file)
    X_test[i, :, :, :] = imageio.imread(file)
# Out:
# reading proj_files/test/000000.png
# reading proj_files/test/000001.png
# reading proj_files/test/000002.png
# reading proj_files/test/000003.png
# reading proj_files/test/000004.png
# reading proj_files/test/000005.png
# reading proj_files/test/000006.png
# reading proj_files/test/000007.png
# reading proj_files/test/000008.png
# reading proj_files/test/000009.png
# reading proj_files/test/000010.png
# reading proj_files/test/000011.png
# reading proj_files/test/000012.png
# reading proj_files/test/000013.png
# reading proj_files/test/000014.png
# reading proj_files/test/000015.png
# reading proj_files/test/000016.png
# reading proj_files/test/000017.png
# reading proj_files/test/000018.png
# reading proj_files/test/000019.png
# reading proj_files/test/000020.png
# reading proj_files/test/000021.png
# reading proj_files/test/000022.png
# reading proj_files/test/000023.png
# reading proj_files/test/000024.png
# reading proj_files/test/000025.png
# reading proj_files/test/000026.png
# reading proj_files/test/000027.png
# reading proj_files/test/000028.png
# reading proj_files/test/000029.png
# reading proj_files/test/000030.png
# reading proj_files/test/000031.png
# reading proj_files/test/000032.png
# reading proj_files/test/000033.png
# reading proj_files/test/000034.png
# reading proj_files/test/000035.png
# reading proj_files/test/000036.png
# reading proj_files/test/000037.png
# reading proj_files/test/000038.png
# reading proj_files/test/000039.png
# reading proj_files/test/000040.png
# reading proj_files/test/000041.png
# reading proj_files/test/000042.png
# reading proj_files/test/000043.png
# reading proj_files/test/000044.png
# reading proj_files/test/000045.png
# reading proj_files/test/000046.png
# reading proj_files/test/000047.png
# reading proj_files/test/000048.png
# reading proj_files/test/000049.png
# reading proj_files/test/000050.png
# reading proj_files/test/000051.png
# reading proj_files/test/000052.png
# reading proj_files/test/000053.png
# reading proj_files/test/000054.png
# reading proj_files/test/000055.png
# reading proj_files/test/000056.png
# reading proj_files/test/000057.png
# reading proj_files/test/000058.png
# reading proj_files/test/000059.png
# reading proj_files/test/000060.png
# reading proj_files/test/000061.png
# reading proj_files/test/000062.png
# reading proj_files/test/000063.png
# reading proj_files/test/000064.png
# reading proj_files/test/000065.png
# reading proj_files/test/000066.png
# reading proj_files/test/000067.png
# reading proj_files/test/000068.png
# reading proj_files/test/000069.png
# reading proj_files/test/000070.png
# reading proj_files/test/000071.png
# reading proj_files/test/000072.png
# reading proj_files/test/000073.png
# reading proj_files/test/000074.png
# reading proj_files/test/000075.png
# reading proj_files/test/000076.png
# reading proj_files/test/000077.png
# reading proj_files/test/000078.png
# reading proj_files/test/000079.png
# reading proj_files/test/000080.png
# reading proj_files/test/000081.png
# reading proj_files/test/000082.png
# reading proj_files/test/000083.png
# reading proj_files/test/000084.png
# reading proj_files/test/000085.png
# reading proj_files/test/000086.png
# reading proj_files/test/000087.png
# reading proj_files/test/000088.png
# reading proj_files/test/000089.png
# reading proj_files/test/000090.png
# reading proj_files/test/000091.png
# reading proj_files/test/000092.png
# reading proj_files/test/000093.png
# reading proj_files/test/000094.png
# reading proj_files/test/000095.png
# reading proj_files/test/000096.png
# reading proj_files/test/000097.png
# reading proj_files/test/000098.png
# reading proj_files/test/000099.png

# %%
X_test_s = X_test / 255

# %%
fig, axes1 = plt.subplots(5, 5, figsize=(8, 8))
for j in range(5):
    for k in range(5):
        i = np.random.choice(range(len(X_test_s)))
        axes1[j][k].set_axis_off()
        axes1[j][k].imshow(X_test_s[i:i+1][0], cmap = 'viridis')

# %%
y_test = model.predict(X_test_s)
# Out:
# /home/ecbm4040/envTF24/lib/python3.6/site-packages/keras/engine/training.py:2470: UserWarning: `Model.state_updates` will be removed in a future version. This property should not be used in TensorFlow 2.0, as `updates` are applied automatically.
#   warnings.warn('`Model.state_updates` will be removed in a future version. '

# %%
y_test_s = y_test
print(np.max(y_test))
# Out:
# 6.09854

# %%
print(np.shape(y_test_s))
# Out:
# (100, 1024, 1024, 3)

# %%
fig, axes1 = plt.subplots(5, 5, figsize=(8, 8))
for j in range(5):
    for k in range(5):
        i = np.random.choice(range(len(y_test_s)))
        axes1[j][k].set_axis_off()
        axes1[j][k].imshow(y_test_s[i:i+1][0], cmap = 'viridis')
# Out:
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# WARNING:matplotlib.image:Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
